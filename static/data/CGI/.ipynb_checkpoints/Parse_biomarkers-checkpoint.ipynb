# %% [markdown]
# # Parse biomarkers from CGI db

# %%
import pandas as pd

# %%
#Read table from CGI https://www.cancergenomeinterpreter.org/biomarkers
df = pd.read_csv('cgi_biomarkers.tsv',sep='\t')

#Get mutation alteration
df = df[df['Alteration type']=='MUT']

#Keep with responsive biomarkers
df = df[df['Association']=='Responsive']

#Select skin and lung cancers
selection = ['CM','LUAD','LUSC','NSCLC']
df = df[df['Primary Tumor type'].isin(selection)]

#Exlude Biomarkers that are not non-synonimous missense muts
df = df[~df['Biomarker'].str.contains('oncogenic mutation|proximal exon|mutation in exon|inframe insertion')]

#Select useful columns
df = df[['Biomarker','Gene','Alteration','Drug','Primary Tumor type','Drug full name','Drug status']].drop_duplicates(['Biomarker','Primary Tumor type'],keep='first')

#Fix alteration column
df['Alteration'] = df['Biomarker'].str.split('(',expand=True)[1].str.split(')',expand=True)[0]

#Exclude those biomarkers without explicit alteration
df = df[~df['Alteration'].isnull()]

#Exclude those biomarkers without explicit drug name
df = df[df['Drug']!='[]']

#Display one mutation per row
df_list = df.values.tolist()
final_list = []
for row in df_list:
    if ',' in row[2]:
        alterations = row[2].split(',')
        num_alt = len(alterations)
        for i in range(0,num_alt):
            new_row = [row[0] , row[1] , alterations[i] , row[3] , row[4] , row[5]]
            final_list.append(new_row)
    else:
        final_list.append(row)
final_df = pd.DataFrame(final_list,columns=df.columns)

#Fix Biomarker column
final_df['Biomarker'] = final_df['Gene'] +'_'+ final_df['Alteration']

#Exclude non-specific alterations
final_df = final_df[~final_df['Alteration'].str.contains('-')]

#Fix Inhibitor type
def inh_type(x):
    if '(' in x:
        if 'etc' in x:
            y = x.split(' (')[0]
        else:
            y = x.split('(')[1].split(')')[0]
    else:
        y = x
    return y

final_df['Inhibitor type'] = final_df['Drug full name'].apply(lambda x: inh_type(x))

#Fix Drug name column
def drug_name(x):
    if '[' in x:
        y = x.split('[')[1].split(']')[0]
    else:
        y = x
    return y
final_df['Drug'] = final_df['Drug'].apply(lambda x: drug_name(x))

#Fix Approved column
final_df['Approved'] = final_df['Drug status'].replace({None:False,'Approved':True, 'FDA approved':True})

#Drop non-useful columns
final_df.drop(columns=['Drug full name','Drug status'],inplace=True)

#Select unique biomarkers per cancer type
final_df.drop_duplicates(['Biomarker','Primary Tumor type','Approved'],keep = 'first',inplace=True)

#One biomarker with an approved drug and a not approved drug -> select the approved one
dupl = final_df[final_df.duplicated(['Biomarker','Primary Tumor type'])]
bm_dupl = dupl['Biomarker'].tolist()[0]
ct_dupl = dupl['Primary Tumor type'].tolist()[0]

final_df = final_df[~((final_df['Biomarker']==bm_dupl)&(final_df['Primary Tumor type']==ct_dupl)&(final_df['Approved']==False))]

final_df
# Out:
#        Biomarker    Gene Alteration                   Drug Primary Tumor type  \
# 0     ALK_E1408V     ALK     E1408V             Brigatinib               LUAD
# 1     ALK_L1196M     ALK     L1196M             Brigatinib               LUAD
# 3     ALK_S1206Y     ALK     S1206Y              Ceritinib               LUAD
# 4     ALK_G1269A     ALK     G1269A              Ceritinib               LUAD
# 5     ALK_I1171T     ALK     I1171T              Ceritinib               LUAD
# 6     ALK_L1198F     ALK     L1198F             Crizotinib               LUAD
# 7     ALK_C1156Y     ALK     C1156Y             Lorlatinib               LUAD
# 8     ARAF_S214C    ARAF      S214C              Sorafenib               LUAD
# 9     BRAF_K601R    BRAF      K601R             Trametinib                 CM
# 10    BRAF_L597R    BRAF      L597R             Trametinib                 CM
# 11    BRAF_V600R    BRAF      V600R             Trametinib                 CM
# 12    BRAF_V600E    BRAF      V600E             Dabrafenib              NSCLC
# 14    BRAF_V600E    BRAF      V600E  Dabrafenib;Trametinib                 CM
# 15    BRAF_V600K    BRAF      V600K  Dabrafenib;Trametinib                 CM
# 16    BRAF_G466V    BRAF      G466V              Dasatinib               LUAD
# 17    BRAF_Y472C    BRAF      Y472C              Dasatinib               LUAD
# 18    BRAF_D594G    BRAF      D594G              Sorafenib                 CM
# 19    BRAF_G469E    BRAF      G469E              Sorafenib                 CM
# 20    BRAF_V600D    BRAF      V600D            Vemurafenib                 CM
# 22    BRAF_V600M    BRAF      V600M            Vemurafenib                 CM
# 23    BRAF_V600G    BRAF      V600G            Vemurafenib                 CM
# 25    DDR2_I638F    DDR2      I638F              Dasatinib               LUSC
# 26    DDR2_L239R    DDR2      L239R              Dasatinib               LUSC
# 27    DDR2_G253C    DDR2      G253C              Dasatinib               LUSC
# 28    DDR2_G774V    DDR2      G774V              Dasatinib               LUSC
# 29     DDR2_L63V    DDR2       L63V              Dasatinib               LUSC
# 30    DDR2_G505S    DDR2      G505S              Dasatinib               LUSC
# 31    DDR2_S768R    DDR2      S768R              Dasatinib               LUSC
# 32    EGFR_T790M    EGFR      T790M    Rociletinib,HM61713              NSCLC
# 34    EGFR_L861Q    EGFR      L861Q               Afatinib              NSCLC
# 35    EGFR_G719A    EGFR      G719A               Afatinib              NSCLC
# 36    EGFR_G719S    EGFR      G719S               Afatinib              NSCLC
# 37    EGFR_G719C    EGFR      G719C               Afatinib              NSCLC
# 38    EGFR_G719D    EGFR      G719D               Afatinib              NSCLC
# 39    EGFR_L747S    EGFR      L747S               Afatinib              NSCLC
# 40    EGFR_S768I    EGFR      S768I               Afatinib              NSCLC
# 41    EGFR_L861P    EGFR      L861P               Afatinib              NSCLC
# 43    EGFR_L861R    EGFR      L861R               Afatinib              NSCLC
# 54    EGFR_L858R    EGFR      L858R              Erlotinib              NSCLC
# 56     EGFR_L861    EGFR       L861              Erlotinib              NSCLC
# 57     EGFR_G719    EGFR       G719              Erlotinib              NSCLC
# 59   ERBB2_G776L   ERBB2      G776L            Trastuzumab               LUAD
# 60   ERBB4_E317K   ERBB4      E317K              Lapatinib                 CM
# 61   ERBB4_E452K   ERBB4      E452K              Lapatinib                 CM
# 62   ERBB4_R544W   ERBB4      R544W              Lapatinib                 CM
# 63   ERBB4_R393W   ERBB4      R393W              Lapatinib                 CM
# 64   ERBB4_E872K   ERBB4      E872K              Lapatinib                 CM
# 65     KIT_D820Y     KIT      D820Y               Imatinib                 CM
# 70  PDGFRA_V658A  PDGFRA      V658A             Crenolanib                 CM
# 71  PDGFRA_P577S  PDGFRA      P577S             Crenolanib                 CM
# 72  PDGFRA_R841K  PDGFRA      R841K             Crenolanib                 CM
# 73  PDGFRA_H845Y  PDGFRA      H845Y             Crenolanib                 CM
# 74  PDGFRA_G853D  PDGFRA      G853D             Crenolanib                 CM
# 79   ROS1_G2032R    ROS1     G2032R           Cabozantinib               LUAD
# 80   ROS1_S1986Y    ROS1     S1986Y             Lorlatinib               LUAD
# 81   ROS1_S1986F    ROS1     S1986F             Lorlatinib               LUAD
#
#                              Inhibitor type  Approved
# 0                          Pan-TK inhibitor     False
# 1                          Pan-TK inhibitor     False
# 3                             ALK inhibitor     False
# 4                             ALK inhibitor     False
# 5                             ALK inhibitor     False
# 6                             ALK inhibitor     False
# 7                        ALK&ROS1 inhibitor     False
# 8                          Pan-TK inhibitor      True
# 9                            MEK inhibitors     False
# 10                           MEK inhibitors     False
# 11                           MEK inhibitors     False
# 12                           BRAF inhibitor     False
# 14           BRAF inhibitor + MEK inhibitor     False
# 15           BRAF inhibitor + MEK inhibitor     False
# 16                BCR-ABL inhibitor 2nd gen     False
# 17                BCR-ABL inhibitor 2nd gen     False
# 18                         Pan-TK inhibitor     False
# 19                         Pan-TK inhibitor     False
# 20                           BRAF inhibitor     False
# 22                           BRAF inhibitor     False
# 23                           BRAF inhibitor     False
# 25                BCR-ABL inhibitor 2nd gen     False
# 26                BCR-ABL inhibitor 2nd gen     False
# 27                BCR-ABL inhibitor 2nd gen     False
# 28                BCR-ABL inhibitor 2nd gen     False
# 29                BCR-ABL inhibitor 2nd gen     False
# 30                BCR-ABL inhibitor 2nd gen     False
# 31                BCR-ABL inhibitor 2nd gen     False
# 32                  EGFR inhibitor 3rd gens     False
# 34   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 35   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 36   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 37   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 38   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 39   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 40   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 41   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 43   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 54                   EGFR inhibitor 1st gen      True
# 56                   EGFR inhibitor 1st gen     False
# 57                   EGFR inhibitor 1st gen     False
# 59                      ERBB2 mAb inhibitor     False
# 60                          ERBB2 inhibitor     False
# 61                          ERBB2 inhibitor     False
# 62                          ERBB2 inhibitor     False
# 63                          ERBB2 inhibitor     False
# 64                          ERBB2 inhibitor     False
# 65  BCR-ABL inhibitor 1st gen&KIT inhibitor     False
# 70                           FLT3 inhibitor     False
# 71                           FLT3 inhibitor     False
# 72                           FLT3 inhibitor     False
# 73                           FLT3 inhibitor     False
# 74                           FLT3 inhibitor     False
# 79                     Pan-kinase inhibitor     False
# 80                       ALK&ROS1 inhibitor     False
# 81                       ALK&ROS1 inhibitor     False

# %%
final_df.groupby('Approved').count()
# Out:
#           Biomarker  Gene  Alteration  Drug  Primary Tumor type  \
# Approved
# False            54    54          54    54                  54
# True              2     2           2     2                   2
#
#           Inhibitor type
# Approved
# False                 54
# True                   2

# %%
final_df[final_df['Approved']==True]
# Out:
#      Biomarker  Gene Alteration       Drug Primary Tumor type  \
# 8   ARAF_S214C  ARAF      S214C  Sorafenib               LUAD
# 54  EGFR_L858R  EGFR      L858R  Erlotinib              NSCLC
#
#             Inhibitor type  Approved
# 8         Pan-TK inhibitor      True
# 54  EGFR inhibitor 1st gen      True

# %%
df1 = final_df.groupby(['Biomarker','Primary Tumor type'],as_index=False).count()
print(len(df1),'biomarkers in total')
# Out:
# 56 biomarkers in total

# %%
cm_df = final_df[final_df['Primary Tumor type']=='CM']
print (len(cm_df.groupby('Biomarker').count()) , 'biomarkers for CM')
# Out:
# 21 biomarkers for CM

# %%
cm_df
# Out:
#        Biomarker    Gene Alteration                   Drug Primary Tumor type  \
# 9     BRAF_K601R    BRAF      K601R             Trametinib                 CM
# 10    BRAF_L597R    BRAF      L597R             Trametinib                 CM
# 11    BRAF_V600R    BRAF      V600R             Trametinib                 CM
# 14    BRAF_V600E    BRAF      V600E  Dabrafenib;Trametinib                 CM
# 15    BRAF_V600K    BRAF      V600K  Dabrafenib;Trametinib                 CM
# 18    BRAF_D594G    BRAF      D594G              Sorafenib                 CM
# 19    BRAF_G469E    BRAF      G469E              Sorafenib                 CM
# 20    BRAF_V600D    BRAF      V600D            Vemurafenib                 CM
# 22    BRAF_V600M    BRAF      V600M            Vemurafenib                 CM
# 23    BRAF_V600G    BRAF      V600G            Vemurafenib                 CM
# 60   ERBB4_E317K   ERBB4      E317K              Lapatinib                 CM
# 61   ERBB4_E452K   ERBB4      E452K              Lapatinib                 CM
# 62   ERBB4_R544W   ERBB4      R544W              Lapatinib                 CM
# 63   ERBB4_R393W   ERBB4      R393W              Lapatinib                 CM
# 64   ERBB4_E872K   ERBB4      E872K              Lapatinib                 CM
# 65     KIT_D820Y     KIT      D820Y               Imatinib                 CM
# 70  PDGFRA_V658A  PDGFRA      V658A             Crenolanib                 CM
# 71  PDGFRA_P577S  PDGFRA      P577S             Crenolanib                 CM
# 72  PDGFRA_R841K  PDGFRA      R841K             Crenolanib                 CM
# 73  PDGFRA_H845Y  PDGFRA      H845Y             Crenolanib                 CM
# 74  PDGFRA_G853D  PDGFRA      G853D             Crenolanib                 CM
#
#                              Inhibitor type  Approved
# 9                            MEK inhibitors     False
# 10                           MEK inhibitors     False
# 11                           MEK inhibitors     False
# 14           BRAF inhibitor + MEK inhibitor     False
# 15           BRAF inhibitor + MEK inhibitor     False
# 18                         Pan-TK inhibitor     False
# 19                         Pan-TK inhibitor     False
# 20                           BRAF inhibitor     False
# 22                           BRAF inhibitor     False
# 23                           BRAF inhibitor     False
# 60                          ERBB2 inhibitor     False
# 61                          ERBB2 inhibitor     False
# 62                          ERBB2 inhibitor     False
# 63                          ERBB2 inhibitor     False
# 64                          ERBB2 inhibitor     False
# 65  BCR-ABL inhibitor 1st gen&KIT inhibitor     False
# 70                           FLT3 inhibitor     False
# 71                           FLT3 inhibitor     False
# 72                           FLT3 inhibitor     False
# 73                           FLT3 inhibitor     False
# 74                           FLT3 inhibitor     False

# %%
lungs = ['LUAD','LUSC','NSCLC']
lung_df = final_df[final_df['Primary Tumor type'].isin(lungs)]
print (len(lung_df.groupby('Biomarker').count()),'biomarkers for lung cancer')
# Out:
# 35 biomarkers for lung cancer

# %%
lung_df
# Out:
#       Biomarker   Gene Alteration                 Drug Primary Tumor type  \
# 0    ALK_E1408V    ALK     E1408V           Brigatinib               LUAD
# 1    ALK_L1196M    ALK     L1196M           Brigatinib               LUAD
# 3    ALK_S1206Y    ALK     S1206Y            Ceritinib               LUAD
# 4    ALK_G1269A    ALK     G1269A            Ceritinib               LUAD
# 5    ALK_I1171T    ALK     I1171T            Ceritinib               LUAD
# 6    ALK_L1198F    ALK     L1198F           Crizotinib               LUAD
# 7    ALK_C1156Y    ALK     C1156Y           Lorlatinib               LUAD
# 8    ARAF_S214C   ARAF      S214C            Sorafenib               LUAD
# 12   BRAF_V600E   BRAF      V600E           Dabrafenib              NSCLC
# 16   BRAF_G466V   BRAF      G466V            Dasatinib               LUAD
# 17   BRAF_Y472C   BRAF      Y472C            Dasatinib               LUAD
# 25   DDR2_I638F   DDR2      I638F            Dasatinib               LUSC
# 26   DDR2_L239R   DDR2      L239R            Dasatinib               LUSC
# 27   DDR2_G253C   DDR2      G253C            Dasatinib               LUSC
# 28   DDR2_G774V   DDR2      G774V            Dasatinib               LUSC
# 29    DDR2_L63V   DDR2       L63V            Dasatinib               LUSC
# 30   DDR2_G505S   DDR2      G505S            Dasatinib               LUSC
# 31   DDR2_S768R   DDR2      S768R            Dasatinib               LUSC
# 32   EGFR_T790M   EGFR      T790M  Rociletinib,HM61713              NSCLC
# 34   EGFR_L861Q   EGFR      L861Q             Afatinib              NSCLC
# 35   EGFR_G719A   EGFR      G719A             Afatinib              NSCLC
# 36   EGFR_G719S   EGFR      G719S             Afatinib              NSCLC
# 37   EGFR_G719C   EGFR      G719C             Afatinib              NSCLC
# 38   EGFR_G719D   EGFR      G719D             Afatinib              NSCLC
# 39   EGFR_L747S   EGFR      L747S             Afatinib              NSCLC
# 40   EGFR_S768I   EGFR      S768I             Afatinib              NSCLC
# 41   EGFR_L861P   EGFR      L861P             Afatinib              NSCLC
# 43   EGFR_L861R   EGFR      L861R             Afatinib              NSCLC
# 54   EGFR_L858R   EGFR      L858R            Erlotinib              NSCLC
# 56    EGFR_L861   EGFR       L861            Erlotinib              NSCLC
# 57    EGFR_G719   EGFR       G719            Erlotinib              NSCLC
# 59  ERBB2_G776L  ERBB2      G776L          Trastuzumab               LUAD
# 79  ROS1_G2032R   ROS1     G2032R         Cabozantinib               LUAD
# 80  ROS1_S1986Y   ROS1     S1986Y           Lorlatinib               LUAD
# 81  ROS1_S1986F   ROS1     S1986F           Lorlatinib               LUAD
#
#                             Inhibitor type  Approved
# 0                         Pan-TK inhibitor     False
# 1                         Pan-TK inhibitor     False
# 3                            ALK inhibitor     False
# 4                            ALK inhibitor     False
# 5                            ALK inhibitor     False
# 6                            ALK inhibitor     False
# 7                       ALK&ROS1 inhibitor     False
# 8                         Pan-TK inhibitor      True
# 12                          BRAF inhibitor     False
# 16               BCR-ABL inhibitor 2nd gen     False
# 17               BCR-ABL inhibitor 2nd gen     False
# 25               BCR-ABL inhibitor 2nd gen     False
# 26               BCR-ABL inhibitor 2nd gen     False
# 27               BCR-ABL inhibitor 2nd gen     False
# 28               BCR-ABL inhibitor 2nd gen     False
# 29               BCR-ABL inhibitor 2nd gen     False
# 30               BCR-ABL inhibitor 2nd gen     False
# 31               BCR-ABL inhibitor 2nd gen     False
# 32                 EGFR inhibitor 3rd gens     False
# 34  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 35  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 36  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 37  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 38  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 39  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 40  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 41  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 43  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 54                  EGFR inhibitor 1st gen      True
# 56                  EGFR inhibitor 1st gen     False
# 57                  EGFR inhibitor 1st gen     False
# 59                     ERBB2 mAb inhibitor     False
# 79                    Pan-kinase inhibitor     False
# 80                      ALK&ROS1 inhibitor     False
# 81                      ALK&ROS1 inhibitor     False

# %%
luad_df = final_df[final_df['Primary Tumor type']=='LUAD']
print (len(luad_df.groupby('Biomarker').count()),'biomarkers for LUAD')
# Out:
# 14 biomarkers for LUAD

# %%
luad_df
# Out:
#       Biomarker   Gene Alteration          Drug Primary Tumor type  \
# 0    ALK_E1408V    ALK     E1408V    Brigatinib               LUAD
# 1    ALK_L1196M    ALK     L1196M    Brigatinib               LUAD
# 3    ALK_S1206Y    ALK     S1206Y     Ceritinib               LUAD
# 4    ALK_G1269A    ALK     G1269A     Ceritinib               LUAD
# 5    ALK_I1171T    ALK     I1171T     Ceritinib               LUAD
# 6    ALK_L1198F    ALK     L1198F    Crizotinib               LUAD
# 7    ALK_C1156Y    ALK     C1156Y    Lorlatinib               LUAD
# 8    ARAF_S214C   ARAF      S214C     Sorafenib               LUAD
# 16   BRAF_G466V   BRAF      G466V     Dasatinib               LUAD
# 17   BRAF_Y472C   BRAF      Y472C     Dasatinib               LUAD
# 59  ERBB2_G776L  ERBB2      G776L   Trastuzumab               LUAD
# 79  ROS1_G2032R   ROS1     G2032R  Cabozantinib               LUAD
# 80  ROS1_S1986Y   ROS1     S1986Y    Lorlatinib               LUAD
# 81  ROS1_S1986F   ROS1     S1986F    Lorlatinib               LUAD
#
#                Inhibitor type  Approved
# 0            Pan-TK inhibitor     False
# 1            Pan-TK inhibitor     False
# 3               ALK inhibitor     False
# 4               ALK inhibitor     False
# 5               ALK inhibitor     False
# 6               ALK inhibitor     False
# 7          ALK&ROS1 inhibitor     False
# 8            Pan-TK inhibitor      True
# 16  BCR-ABL inhibitor 2nd gen     False
# 17  BCR-ABL inhibitor 2nd gen     False
# 59        ERBB2 mAb inhibitor     False
# 79       Pan-kinase inhibitor     False
# 80         ALK&ROS1 inhibitor     False
# 81         ALK&ROS1 inhibitor     False

# %%
lusc_df = final_df[final_df['Primary Tumor type']=='LUSC']
print(len(lusc_df.groupby('Biomarker').count()),'biomarkers for LUSC')
# Out:
# 7 biomarkers for LUSC

# %%
lusc_df
# Out:
#      Biomarker  Gene Alteration       Drug Primary Tumor type  \
# 25  DDR2_I638F  DDR2      I638F  Dasatinib               LUSC
# 26  DDR2_L239R  DDR2      L239R  Dasatinib               LUSC
# 27  DDR2_G253C  DDR2      G253C  Dasatinib               LUSC
# 28  DDR2_G774V  DDR2      G774V  Dasatinib               LUSC
# 29   DDR2_L63V  DDR2       L63V  Dasatinib               LUSC
# 30  DDR2_G505S  DDR2      G505S  Dasatinib               LUSC
# 31  DDR2_S768R  DDR2      S768R  Dasatinib               LUSC
#
#                Inhibitor type  Approved
# 25  BCR-ABL inhibitor 2nd gen     False
# 26  BCR-ABL inhibitor 2nd gen     False
# 27  BCR-ABL inhibitor 2nd gen     False
# 28  BCR-ABL inhibitor 2nd gen     False
# 29  BCR-ABL inhibitor 2nd gen     False
# 30  BCR-ABL inhibitor 2nd gen     False
# 31  BCR-ABL inhibitor 2nd gen     False

# %%
nsclc_df = final_df[final_df['Primary Tumor type']=='NSCLC']
print(len(nsclc_df.groupby('Biomarker').count()),'biomarkers for NSCLC')
# Out:
# 14 biomarkers for NSCLC

# %%
nsclc_df
# Out:
#      Biomarker  Gene Alteration                 Drug Primary Tumor type  \
# 12  BRAF_V600E  BRAF      V600E           Dabrafenib              NSCLC
# 32  EGFR_T790M  EGFR      T790M  Rociletinib,HM61713              NSCLC
# 34  EGFR_L861Q  EGFR      L861Q             Afatinib              NSCLC
# 35  EGFR_G719A  EGFR      G719A             Afatinib              NSCLC
# 36  EGFR_G719S  EGFR      G719S             Afatinib              NSCLC
# 37  EGFR_G719C  EGFR      G719C             Afatinib              NSCLC
# 38  EGFR_G719D  EGFR      G719D             Afatinib              NSCLC
# 39  EGFR_L747S  EGFR      L747S             Afatinib              NSCLC
# 40  EGFR_S768I  EGFR      S768I             Afatinib              NSCLC
# 41  EGFR_L861P  EGFR      L861P             Afatinib              NSCLC
# 43  EGFR_L861R  EGFR      L861R             Afatinib              NSCLC
# 54  EGFR_L858R  EGFR      L858R            Erlotinib              NSCLC
# 56   EGFR_L861  EGFR       L861            Erlotinib              NSCLC
# 57   EGFR_G719  EGFR       G719            Erlotinib              NSCLC
#
#                             Inhibitor type  Approved
# 12                          BRAF inhibitor     False
# 32                 EGFR inhibitor 3rd gens     False
# 34  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 35  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 36  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 37  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 38  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 39  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 40  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 41  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 43  ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 54                  EGFR inhibitor 1st gen      True
# 56                  EGFR inhibitor 1st gen     False
# 57                  EGFR inhibitor 1st gen     False

# %%
final_df.to_csv('selected_biomarkers.tsv',sep='\t',index=False)

# %%
df = pd.read_csv('selected_biomarkers.tsv',sep='\t')
df
# Out:
#        Biomarker    Gene Alteration                   Drug Primary Tumor type  \
# 0     ALK_E1408V     ALK     E1408V             Brigatinib               LUAD
# 1     ALK_L1196M     ALK     L1196M             Brigatinib               LUAD
# 2     ALK_S1206Y     ALK     S1206Y              Ceritinib               LUAD
# 3     ALK_G1269A     ALK     G1269A              Ceritinib               LUAD
# 4     ALK_I1171T     ALK     I1171T              Ceritinib               LUAD
# 5     ALK_L1198F     ALK     L1198F             Crizotinib               LUAD
# 6     ALK_C1156Y     ALK     C1156Y             Lorlatinib               LUAD
# 7     ARAF_S214C    ARAF      S214C              Sorafenib               LUAD
# 8     BRAF_K601R    BRAF      K601R             Trametinib                 CM
# 9     BRAF_L597R    BRAF      L597R             Trametinib                 CM
# 10    BRAF_V600R    BRAF      V600R             Trametinib                 CM
# 11    BRAF_V600E    BRAF      V600E             Dabrafenib              NSCLC
# 12    BRAF_V600E    BRAF      V600E  Dabrafenib;Trametinib                 CM
# 13    BRAF_V600K    BRAF      V600K  Dabrafenib;Trametinib                 CM
# 14    BRAF_G466V    BRAF      G466V              Dasatinib               LUAD
# 15    BRAF_Y472C    BRAF      Y472C              Dasatinib               LUAD
# 16    BRAF_D594G    BRAF      D594G              Sorafenib                 CM
# 17    BRAF_G469E    BRAF      G469E              Sorafenib                 CM
# 18    BRAF_V600D    BRAF      V600D            Vemurafenib                 CM
# 19    BRAF_V600M    BRAF      V600M            Vemurafenib                 CM
# 20    BRAF_V600G    BRAF      V600G            Vemurafenib                 CM
# 21    DDR2_I638F    DDR2      I638F              Dasatinib               LUSC
# 22    DDR2_L239R    DDR2      L239R              Dasatinib               LUSC
# 23    DDR2_G253C    DDR2      G253C              Dasatinib               LUSC
# 24    DDR2_G774V    DDR2      G774V              Dasatinib               LUSC
# 25     DDR2_L63V    DDR2       L63V              Dasatinib               LUSC
# 26    DDR2_G505S    DDR2      G505S              Dasatinib               LUSC
# 27    DDR2_S768R    DDR2      S768R              Dasatinib               LUSC
# 28    EGFR_T790M    EGFR      T790M    Rociletinib,HM61713              NSCLC
# 29    EGFR_L861Q    EGFR      L861Q               Afatinib              NSCLC
# 30    EGFR_G719A    EGFR      G719A               Afatinib              NSCLC
# 31    EGFR_G719S    EGFR      G719S               Afatinib              NSCLC
# 32    EGFR_G719C    EGFR      G719C               Afatinib              NSCLC
# 33    EGFR_G719D    EGFR      G719D               Afatinib              NSCLC
# 34    EGFR_L747S    EGFR      L747S               Afatinib              NSCLC
# 35    EGFR_S768I    EGFR      S768I               Afatinib              NSCLC
# 36    EGFR_L861P    EGFR      L861P               Afatinib              NSCLC
# 37    EGFR_L861R    EGFR      L861R               Afatinib              NSCLC
# 38    EGFR_L858R    EGFR      L858R              Erlotinib              NSCLC
# 39     EGFR_L861    EGFR       L861              Erlotinib              NSCLC
# 40     EGFR_G719    EGFR       G719              Erlotinib              NSCLC
# 41   ERBB2_G776L   ERBB2      G776L            Trastuzumab               LUAD
# 42   ERBB4_E317K   ERBB4      E317K              Lapatinib                 CM
# 43   ERBB4_E452K   ERBB4      E452K              Lapatinib                 CM
# 44   ERBB4_R544W   ERBB4      R544W              Lapatinib                 CM
# 45   ERBB4_R393W   ERBB4      R393W              Lapatinib                 CM
# 46   ERBB4_E872K   ERBB4      E872K              Lapatinib                 CM
# 47     KIT_D820Y     KIT      D820Y               Imatinib                 CM
# 48  PDGFRA_V658A  PDGFRA      V658A             Crenolanib                 CM
# 49  PDGFRA_P577S  PDGFRA      P577S             Crenolanib                 CM
# 50  PDGFRA_R841K  PDGFRA      R841K             Crenolanib                 CM
# 51  PDGFRA_H845Y  PDGFRA      H845Y             Crenolanib                 CM
# 52  PDGFRA_G853D  PDGFRA      G853D             Crenolanib                 CM
# 53   ROS1_G2032R    ROS1     G2032R           Cabozantinib               LUAD
# 54   ROS1_S1986Y    ROS1     S1986Y             Lorlatinib               LUAD
# 55   ROS1_S1986F    ROS1     S1986F             Lorlatinib               LUAD
#
#                              Inhibitor type  Approved
# 0                          Pan-TK inhibitor     False
# 1                          Pan-TK inhibitor     False
# 2                             ALK inhibitor     False
# 3                             ALK inhibitor     False
# 4                             ALK inhibitor     False
# 5                             ALK inhibitor     False
# 6                        ALK&ROS1 inhibitor     False
# 7                          Pan-TK inhibitor      True
# 8                            MEK inhibitors     False
# 9                            MEK inhibitors     False
# 10                           MEK inhibitors     False
# 11                           BRAF inhibitor     False
# 12           BRAF inhibitor + MEK inhibitor     False
# 13           BRAF inhibitor + MEK inhibitor     False
# 14                BCR-ABL inhibitor 2nd gen     False
# 15                BCR-ABL inhibitor 2nd gen     False
# 16                         Pan-TK inhibitor     False
# 17                         Pan-TK inhibitor     False
# 18                           BRAF inhibitor     False
# 19                           BRAF inhibitor     False
# 20                           BRAF inhibitor     False
# 21                BCR-ABL inhibitor 2nd gen     False
# 22                BCR-ABL inhibitor 2nd gen     False
# 23                BCR-ABL inhibitor 2nd gen     False
# 24                BCR-ABL inhibitor 2nd gen     False
# 25                BCR-ABL inhibitor 2nd gen     False
# 26                BCR-ABL inhibitor 2nd gen     False
# 27                BCR-ABL inhibitor 2nd gen     False
# 28                  EGFR inhibitor 3rd gens     False
# 29   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 30   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 31   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 32   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 33   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 34   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 35   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 36   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 37   ERBB2 inhibitor&EGFR inhibitor 2nd gen     False
# 38                   EGFR inhibitor 1st gen      True
# 39                   EGFR inhibitor 1st gen     False
# 40                   EGFR inhibitor 1st gen     False
# 41                      ERBB2 mAb inhibitor     False
# 42                          ERBB2 inhibitor     False
# 43                          ERBB2 inhibitor     False
# 44                          ERBB2 inhibitor     False
# 45                          ERBB2 inhibitor     False
# 46                          ERBB2 inhibitor     False
# 47  BCR-ABL inhibitor 1st gen&KIT inhibitor     False
# 48                           FLT3 inhibitor     False
# 49                           FLT3 inhibitor     False
# 50                           FLT3 inhibitor     False
# 51                           FLT3 inhibitor     False
# 52                           FLT3 inhibitor     False
# 53                     Pan-kinase inhibitor     False
# 54                       ALK&ROS1 inhibitor     False
# 55                       ALK&ROS1 inhibitor     False
